# %%
import pandas as pd

# %%
df = pd.read_csv("Columbus_Salary_data_cleaned.csv")
df.head()
# Out:
#                company_txt        job_simp  \
# 0                    IBM\n  data scientist
# 1  Upstart Network, Inc.\n  data scientist
# 2               Battelle\n  data scientist
# 3                  Olive\n   data engineer
# 4                  Olive\n     ML Engineer
#
#                                      Job Description  \
# 0  Introduction\nAs a Data Scientist at IBM, you ...
# 1  Upstart is a leading AI lending platform partn...
# 2  Battelles founding mission to translate scient...
# 3  Olive is healthcare's A.I. workforce and has b...
# 4  Olive is healthcare's first intelligent digita...
#
#                 Salary Estimate  Rating      Location job_state  \
# 0  $80K-$129K\n(Glassdoor est.)     3.8  Columbus, OH        OH
# 1  $89K-$147K\n(Glassdoor est.)     4.3  Columbus, OH        OH
# 2  $96K-$157K\n(Glassdoor est.)     3.3  Columbus, OH        OH
# 3   $52K-$94K\n(Glassdoor est.)     3.8  Columbus, OH        OH
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                          company_txt        job_simp  \
# 0  The Ohio State University Wexner Medical Cente...              na
# 1                          Upstart Network, Inc.\r\n              na
# 2    International Business Machines Corporation\r\n  data scientist
# 3                           Berger Health System\r\n  data scientist
# 4                                          Olive\r\n     ML Engineer
#
#                                      Job Description  \
# 0  Job Details\r\nJob Title\r\nResearch Scientist...
# 1  Upstart is a leading AI lending platform partn...
# 2  Introduction\r\nAs a Data Scientist at IBM, yo...
# 3  We are more than a health system. We are a bel...
# 4  Olive is healthcare's first intelligent digita...
#
#                   Salary Estimate  Rating      Location job_state  \
# 0   $42K-$92K\r\n(Glassdoor est.)     3.9  Columbus, OH        OH
# 1  $54K-$111K\r\n(Glassdoor est.)     4.5  Columbus, OH        OH
# 2   $54K-$89K\r\n(Glassdoor est.)     3.8  Columbus, OH        OH
# 3  $63K-$105K\r\n(Glassdoor est.)     3.6    Dublin, OH        OH
# 4   $48K-$89K\r\n(Glassdoor est.)     3.7  Columbus, OH        OH
#
#                     Size  Founded  Type of ownership  ... python_yn sql_yn  \
# 0       10000+ Employees     1916           Hospital  ...         0      0
# 1   201 to 500 Employees     2012  Company - Private  ...         1      0
# 2       10000+ Employees     1911   Company - Public  ...         1      0
# 3  501 to 1000 Employees       -1           Hospital  ...         1      1
# 4   201 to 500 Employees     2012  Company - Private  ...         1      1
#
#   excel_yn  aws_yn  spark_yn  nlp_yn  r studio_yn  job_sin  \
# 0        0       0         0       0            0       na
# 1        0       0         0       0            0       na
# 2        0       0         1       0            0   junior
# 3        1       0         0       0            0       na
# 4        0       0         0       0            0       na
#
#                                         Company Name  \
# 0  The Ohio State University Wexner Medical Cente...
# 1                       Upstart Network, Inc.\r\n4.5
# 2  International Business Machines Corporation\r\...
# 3                        Berger Health System\r\n3.6
# 4                                       Olive\r\n3.7
#
#                               Job Title
# 0                    Research Scientist
# 1                    Research Scientist
# 2  Junior Data Scientist Apprenticeship
# 3                        Data Scientist
# 4             Machine Learning Engineer
#
# [5 rows x 30 columns]

# %%
df.job_simp.value_counts()
# Out:
# na                15
# data scientist     9
# data engineer      6
# analyst            3
# manager            1
# ML Engineer        1
# Name: job_simp, dtype: int64

# %%
df.min_degree.value_counts()
# Out:
# Bachelors    26
# Masters       9
# Name: min_degree, dtype: int64

# %%
#Job description Length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))

# %%
#hourly wage to annual 
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis = 1)

# %%
df[df.hourly==1][['hourly','min_salary','max_salary']]
# Out:
# Empty DataFrame
# Columns: [hourly, min_salary, max_salary]
# Index: []

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n',''))

# %%
df.describe()
# Out:
#           Rating      Founded  hourly  employer provided  min_salary  \
# count  35.000000    35.000000    35.0               35.0   35.000000
# mean    3.648571  1876.885714     0.0                0.0   71.000000
# std     0.339871   333.841612     0.0                0.0   32.661364
# min     3.200000    -1.000000     0.0                0.0   25.000000
# 25%     3.300000  1890.000000     0.0                0.0   48.000000
# 50%     3.700000  1929.000000     0.0                0.0   62.000000
# 75%     3.800000  1990.000000     0.0                0.0   90.500000
# max     4.500000  2015.000000     0.0                0.0  144.000000
#
#        max_salary  avg_salary         age  python_yn    sql_yn   excel_yn  \
# count   35.000000   35.000000   35.000000  35.000000  35.00000  35.000000
# mean   122.228571   96.614286   85.342857   0.542857   0.40000   0.485714
# std     44.566596   38.052419   70.043660   0.505433   0.49705   0.507093
# min     60.000000   42.500000   -1.000000   0.000000   0.00000   0.000000
# 25%     91.500000   70.500000   16.500000   0.000000   0.00000   0.000000
# 50%    115.000000   90.500000   91.000000   1.000000   0.00000   0.000000
# 75%    143.000000  116.500000  128.000000   1.000000   1.00000   1.000000
# max    238.000000  189.000000  221.000000   1.000000   1.00000   1.000000
#
#           aws_yn   spark_yn     nlp_yn  r studio_yn     desc_len
# count  35.000000  35.000000  35.000000         35.0    35.000000
# mean    0.171429   0.142857   0.028571          0.0  4269.000000
# std     0.382385   0.355036   0.169031          0.0  1798.721049
# min     0.000000   0.000000   0.000000          0.0  1454.000000
# 25%     0.000000   0.000000   0.000000          0.0  2986.500000
# 50%     0.000000   0.000000   0.000000          0.0  3728.000000
# 75%     0.000000   0.000000   0.000000          0.0  5417.500000
# max     1.000000   1.000000   1.000000          0.0  7754.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age','avg_salary', 'Rating'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['age','avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.244425  0.070073  0.398284
# avg_salary  0.244425    1.000000  0.026052  0.043281
# Rating      0.070073    0.026052  1.000000 -0.230431
# desc_len    0.398284    0.043281 -0.230431  1.000000

# %%
cmap = sns.diverging_palette(220,10, as_cmap=True)
sns.heatmap(df[['age','avg_salary', 'Rating', 'desc_len']].corr(),vmax =.3, center = 0, cmap=cmap,
            square=True, linewidth=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['company_txt', 'job_simp', 'Job Description', 'Salary Estimate',
#        'Rating', 'Location', 'job_state', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'employer provided', 'min_salary', 'max_salary', 'avg_salary',
#        'min_degree', 'age', 'python_yn', 'sql_yn', 'excel_yn', 'aws_yn',
#        'spark_yn', 'nlp_yn', 'r studio_yn', 'job_sin', 'Company Name',
#        'Job Title', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Industry','Revenue','company_txt','python_yn', 'sql_yn', 'excel_yn', 'aws_yn',
       'spark_yn','job_simp','job_sin','min_degree',]]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("Graph for %s: total =%d" %(i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# Graph for Industry: total =13
# Graph for Revenue: total =8
# Graph for company_txt: total =19
# C:\Users\Jen butt\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jen butt\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Graph for python_yn: total =2
# Graph for sql_yn: total =2
# Graph for excel_yn: total =2
# Graph for aws_yn: total =2
# Graph for spark_yn: total =2
# Graph for job_simp: total =6
# Graph for job_sin: total =3
# Graph for min_degree: total =2

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# ML Engineer      68.500000
# analyst          64.166667
# data engineer    92.916667
# data scientist  124.666667
# manager          66.500000
# na               91.633333

# %%
pd.pivot_table(df, index = ['job_simp','job_sin'], values = 'avg_salary')
# Out:
#                         avg_salary
# job_simp       job_sin
# ML Engineer    na        68.500000
# analyst        na        64.166667
# data engineer  na        82.250000
#                senior   114.250000
# data scientist junior    71.500000
#                na       107.375000
#                senior   155.250000
# manager        na        66.500000
# na             na        76.777778
#                senior   113.916667

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    #remove punctuation and stop words#
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered
words_filtered = punctuation_stop(words)

text = " ".join({ele for ele in words_filtered})

wc = WordCloud(background_color = "white", max_words = 2000, max_font_size=90, random_state=1, stopwords=STOPWORDS)
wc.generate(text)


plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda.csv')
